# %%
import os
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
import math
import time

from Nuscenes_dataset_test import NuscenesDatasetTest
from Model import EnDeWithPooling, EnDeConvLSTM_ws, SkipLSTMEnDe
from torchvision import transforms
from PIL import Image

# %%
def saveTransformedImages(imageTensor):
    to_pil = torchvision.transforms.ToPILImage()
    im = to_pil(imageTensor)
    mn, mx = np.min(im), np.max(im)
    im = (im - mn) / (mx - mn)
    print(im)
    plt.imshow(im, cmap='gray')
    plt.show()

# %%
def plotTrajectory(xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti, seqLen, im_path, numFrames=None):
    fig = plt.figure(figsize=(8, 8))
    plt.plot(yValsGT, xValsGT, c='r', label='Ground Truth')
    plt.plot(yValsPred, xValsPred, c='g', label='Prediction')
    plt.plot(yValsPredMulti, xValsPredMulti, c='b', label='Multimodal Prediction', alpha=0.8)
    axes = plt.gca()
    axes.set_xlim([1, 512])
    axes.set_ylim([1, 512])
    plt.xlabel('X-Axis')
    plt.ylabel('Y-Axis')
    plt.legend(loc='upper right')
    if numFrames == None:
        plt.title('Trajectory')
    else:
        plot_title = 'Trajectory (' + str(numFrames // 10 - 2) + "s)"
        plt.title(plot_title)
    plt.savefig(im_path)
    plt.close()

# %%
def heatmapAccuracy(outputMap, labelMap, thr=1.5):
    pred = np.unravel_index(outputMap.argmax(), outputMap.shape)
    gt = np.unravel_index(labelMap.argmax(), labelMap.shape)

    dist = math.sqrt((pred[0] - gt[0]) ** 2 + (pred[1] - gt[1]) ** 2)
    if dist <= thr:
        return 1, dist, (pred[0], pred[1]), (gt[0], gt[1])
    return 0, dist, (pred[0], pred[1]), (gt[0], gt[1])

# %%
def largest_indices(ary, n):
    """Returns the n largest indices from a numpy array."""
    flat = ary.flatten()
    indices = np.argpartition(flat, -n)[-n:]
    indices = indices[np.argsort(-flat[indices])]
    return np.unravel_index(indices, ary.shape)

# %%
def multiAccuracy(outputMap, labelMap, topK=5):
    pred = largest_indices(outputMap, topK)
    gt = np.unravel_index(labelMap.argmax(), labelMap.shape)
    dist_arr = []
    for i in range(len(pred[0])):
        dist = math.sqrt((pred[0][i] - gt[0]) ** 2 + (pred[1][i] - gt[1]) ** 2)
        dist_arr.append(dist)
    
    min_val = np.min(dist_arr)
    min_idx = np.argmin(dist_arr)
    within_radius = 0
    if min_val <= 4:
        within_radius = 1
    return 0, min_val, (pred[0][min_idx], pred[1][min_idx]), (gt[0], gt[1]), within_radius

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %% [markdown]
# ### Set Cross Validation No

# %%
checkpoint_path = "/home/sas115/trajectory_prediction_INFER-master/ablation_cache/skipLSTM/split-0/checkpoint_future_best.tar"

# %%
# Choose the corresponding model for each split
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-0", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-1", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-2", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-3", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-4", "checkpoint_future.tar")

# %%
checkpoint = torch.load(checkpoint_path)
model = SkipLSTMEnDe(activation="relu", initType="default", numChannels=5, imageHeight=256, imageWidth=256, batchnorm=False, softmax=False)
model.load_state_dict(checkpoint["model_state_dict"])
model = model.cuda()
model.convlstm = model.convlstm.cuda()

# %%
# data_dir = "/home/fbd/rrc/submission/INFER-datasets/kitti"
# val_dir = os.path.join(data_dir, "final-validation", "test" + str(cv_num) + ".csv")
# val_dataset = KittiDataset(data_dir, height=256, width=256, train=False, infoPath=val_dir, augmentation=False, groundTruth=True)

# %%
data_dir = "/home/sas115/trajectory_prediction_INFER-master/nuScenes_project_dataset_val"
val_dataset = NuscenesDatasetTest(data_dir, height=256, width=256,)

# %% [markdown]
# ### Future Prediction (Final, Validation)

# %%
upsample_512 = torch.nn.Upsample(scale_factor=2, mode='bilinear')
labelTransform = transforms.Compose([
    transforms.ToTensor()
])
targetGTDir = os.path.join(data_dir, 'targetGT')
valLoss1, valLoss2, valLoss3, valLoss4, valLoss, valLoss8 = [], [], [], [], [], []
topK = 5
totalPreds = 0
hitPreds = 0

# %%
debug, prevOut, state = True, None, None
prevChannels = None
xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti = [], [], [], [], [], []
seqLoss, seqVals = [], []
seqNum, seqLen = 0, 0

start_time = time.time()
model.eval()
new_seq_loss = []

for i in range(len(val_dataset)):
    grid, sceneNum, seqNum, frame_num, endOfSequence = val_dataset[i]
    grid = grid.type(torch.cuda.FloatTensor)
    
    # The Last Channel is the target frame and first n - 1 are source frames
    inp = grid[:-1, :].unsqueeze(0).to(device)
    currLabel = grid[-1:, :].unsqueeze(0).to(device)
    
    if frame_num < 4:
        prevChannels = inp

    if frame_num >= 4:
        new_inp = inp.clone().squeeze(0)
        mn, mx = torch.min(prevOut), torch.max(prevOut)
        prevOut = (prevOut - mn) / (mx - mn)
        new_inp[0] = prevOut
        new_inp[4] = prevChannels[0, 4, :, :]        
        inp = new_inp.unsqueeze(0).cuda()

    # Forward the input and obtain the result
    out = model.forward(inp, state)
    state = (model.h, model.c, model.h1, model.c1, model.h2, model.c2)
    currOutputMap = out.clone()
    newOutputMap = upsample_512(currOutputMap)
    
    nextTargetTensor = grid[5,:,:]
    
    #import pdb; pdb.set_trace()
    
    prevOut = currOutputMap.detach().cpu().squeeze(0).squeeze(0)
    currOutputMap = currOutputMap.detach().cpu().numpy().squeeze(0).squeeze(0)
    currLabel = currLabel.detach().cpu().numpy().squeeze(0).squeeze(0)
    
    # Upsampled outputs and inputs
    currOutputMap1 = newOutputMap.detach().cpu().numpy().squeeze(0).squeeze(0)
    currLabel1 = nextTargetTensor.detach().cpu().numpy()
    
    _, dist1, predCoordinates1, gtCoordinates1 = heatmapAccuracy(currOutputMap1, currLabel1)
    _, dist2, predCoordinates2, gtCoordinates2, within_radius = multiAccuracy(currOutputMap1, currLabel1, topK=topK)
    
    if frame_num >= 4:
        seqLoss.append(dist2)
        new_seq_loss.append([dist2])        
        totalPreds += 1
        if within_radius == 1:
            hitPreds += 1

    seqLen += 1
    xValsGT.append(gtCoordinates1[0])
    yValsGT.append(gtCoordinates1[1])
    xValsPred.append(predCoordinates1[0])
    yValsPred.append(predCoordinates1[1])
    xValsPredMulti.append(predCoordinates2[0])
    yValsPredMulti.append(predCoordinates2[1])
    
    if endOfSequence:
        seqVals.append(seqLen)
        xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti = [], [], [], [], [], []
        seqNum +=1
        state = None
        valLoss.append(np.mean(seqLoss))
        valLoss8.append(np.mean(seqLoss[:8]))
        valLoss1.append(np.mean(seqLoss[:10]))
        valLoss2.append(np.mean(seqLoss[:20]))
        valLoss3.append(np.mean(seqLoss[:30]))
        valLoss4.append(np.mean(seqLoss[:40]))
        print("Scene: {}, Sequence: {}, Frame: {}, Seq Loss: {}".format(sceneNum, seqNum, frame_num, np.mean(seqLoss)))
        seqLoss = []

end_time = time.time()
# Out:
# Scene: 12.0, Sequence: 1.0, Frame: 11, Seq Loss: 200.48098731524396
# Scene: 12.0, Sequence: 2.0, Frame: 11, Seq Loss: 199.2193574931726
# Scene: 12.0, Sequence: 3.0, Frame: 11, Seq Loss: 205.20689173521825
# Scene: 12.0, Sequence: 4.0, Frame: 11, Seq Loss: 210.07784876142318
# Scene: 12.0, Sequence: 5.0, Frame: 11, Seq Loss: 288.8139240545304
# Scene: 12.0, Sequence: 6.0, Frame: 11, Seq Loss: 214.47413972454655
# Scene: 12.0, Sequence: 7.0, Frame: 11, Seq Loss: 224.47396687752885
# Scene: 12.0, Sequence: 8.0, Frame: 11, Seq Loss: 349.44704540636303
# Scene: 12.0, Sequence: 9.0, Frame: 11, Seq Loss: 232.98642587600042
# Scene: 12.0, Sequence: 10.0, Frame: 11, Seq Loss: 228.41720435141315
# Scene: 12.0, Sequence: 11.0, Frame: 11, Seq Loss: 341.4325695911442
# Scene: 12.0, Sequence: 12.0, Frame: 11, Seq Loss: 212.54397135255866
# Scene: 12.0, Sequence: 13.0, Frame: 11, Seq Loss: 248.83067183266198
# Scene: 12.0, Sequence: 14.0, Frame: 11, Seq Loss: 243.21400698986406
# Scene: 12.0, Sequence: 15.0, Frame: 11, Seq Loss: 216.94912072512034
# Scene: 12.0, Sequence: 16.0, Frame: 11, Seq Loss: 326.67344817716213
# Scene: 12.0, Sequence: 17.0, Frame: 11, Seq Loss: 216.84103132562092
# Scene: 12.0, Sequence: 18.0, Frame: 11, Seq Loss: 235.92907335514914
# Scene: 12.0, Sequence: 19.0, Frame: 11, Seq Loss: 192.74179791145366
# Scene: 12.0, Sequence: 20.0, Frame: 11, Seq Loss: 220.84788240338173
# Scene: 12.0, Sequence: 21.0, Frame: 11, Seq Loss: 216.25465867120997
# Scene: 12.0, Sequence: 22.0, Frame: 11, Seq Loss: 225.6498650597125
# Scene: 12.0, Sequence: 23.0, Frame: 11, Seq Loss: 219.66239994492517
# Scene: 12.0, Sequence: 24.0, Frame: 11, Seq Loss: 228.77597646588936
# Scene: 12.0, Sequence: 25.0, Frame: 11, Seq Loss: 254.40583599945472
# Scene: 12.0, Sequence: 26.0, Frame: 11, Seq Loss: 210.2831411269126
# Scene: 13.0, Sequence: 1.0, Frame: 11, Seq Loss: 193.26917708141093
# Scene: 13.0, Sequence: 2.0, Frame: 11, Seq Loss: 195.1127225638415
# Scene: 13.0, Sequence: 3.0, Frame: 11, Seq Loss: 198.2571958466753
# Scene: 13.0, Sequence: 4.0, Frame: 11, Seq Loss: 196.94443744881931
# Scene: 13.0, Sequence: 5.0, Frame: 11, Seq Loss: 191.86537996439324
# Scene: 13.0, Sequence: 6.0, Frame: 11, Seq Loss: 192.8472953561541
# Scene: 13.0, Sequence: 7.0, Frame: 11, Seq Loss: 199.15843964280245
# Scene: 13.0, Sequence: 8.0, Frame: 11, Seq Loss: 206.86596536407612
# Scene: 13.0, Sequence: 9.0, Frame: 11, Seq Loss: 209.74642495227678
# Scene: 13.0, Sequence: 10.0, Frame: 11, Seq Loss: 201.91156977902736
# Scene: 13.0, Sequence: 11.0, Frame: 11, Seq Loss: 198.5533557463553
# Scene: 13.0, Sequence: 12.0, Frame: 11, Seq Loss: 193.5537623833336
# Scene: 13.0, Sequence: 13.0, Frame: 11, Seq Loss: 193.13428747100332
# Scene: 13.0, Sequence: 14.0, Frame: 11, Seq Loss: 215.41444528372102
# Scene: 13.0, Sequence: 15.0, Frame: 11, Seq Loss: 211.7269522974479
# Scene: 13.0, Sequence: 16.0, Frame: 11, Seq Loss: 220.5419810962952
# Scene: 13.0, Sequence: 17.0, Frame: 11, Seq Loss: 218.46187091245352
# Scene: 13.0, Sequence: 18.0, Frame: 11, Seq Loss: 197.67978212091487
# Scene: 13.0, Sequence: 19.0, Frame: 11, Seq Loss: 218.98900427010528
# Scene: 13.0, Sequence: 20.0, Frame: 11, Seq Loss: 225.61207254337555
# Scene: 13.0, Sequence: 21.0, Frame: 11, Seq Loss: 225.33153744485264
# Scene: 13.0, Sequence: 22.0, Frame: 11, Seq Loss: 211.4471524070428
# Scene: 13.0, Sequence: 23.0, Frame: 11, Seq Loss: 180.19413450807855
# Scene: 13.0, Sequence: 24.0, Frame: 11, Seq Loss: 222.51037582446594
# Scene: 13.0, Sequence: 25.0, Frame: 11, Seq Loss: 246.1616068728993
# Scene: 13.0, Sequence: 26.0, Frame: 11, Seq Loss: 216.54150972272225
# Scene: 14.0, Sequence: 1.0, Frame: 11, Seq Loss: 227.84813988829342
# Scene: 14.0, Sequence: 2.0, Frame: 11, Seq Loss: 176.4191427680548
# Scene: 14.0, Sequence: 3.0, Frame: 11, Seq Loss: 169.5935383831482
# Scene: 14.0, Sequence: 4.0, Frame: 11, Seq Loss: 170.37178291364847
# Scene: 14.0, Sequence: 5.0, Frame: 11, Seq Loss: 207.22749751971335
# Scene: 14.0, Sequence: 6.0, Frame: 11, Seq Loss: 198.37559677783037
# Scene: 14.0, Sequence: 7.0, Frame: 11, Seq Loss: 196.90643498221795
# Scene: 14.0, Sequence: 8.0, Frame: 11, Seq Loss: 217.19329348994617
# Scene: 14.0, Sequence: 9.0, Frame: 11, Seq Loss: 222.4130250437911
# Scene: 14.0, Sequence: 10.0, Frame: 11, Seq Loss: 217.31786367792753
# Scene: 14.0, Sequence: 11.0, Frame: 11, Seq Loss: 211.70536780270174
# Scene: 14.0, Sequence: 12.0, Frame: 11, Seq Loss: 183.10514190161558
# Scene: 14.0, Sequence: 13.0, Frame: 11, Seq Loss: 180.0601262790524
# Scene: 14.0, Sequence: 14.0, Frame: 11, Seq Loss: 220.64470309656156
# Scene: 14.0, Sequence: 15.0, Frame: 11, Seq Loss: 203.97410312952022
# Scene: 14.0, Sequence: 16.0, Frame: 11, Seq Loss: 181.19816068178045
# Scene: 14.0, Sequence: 17.0, Frame: 11, Seq Loss: 223.88772573130677
# Scene: 14.0, Sequence: 18.0, Frame: 11, Seq Loss: 235.15351300612622
# Scene: 14.0, Sequence: 19.0, Frame: 11, Seq Loss: 258.6346115373382
# Scene: 14.0, Sequence: 20.0, Frame: 11, Seq Loss: 213.42395250828838
# Scene: 14.0, Sequence: 21.0, Frame: 11, Seq Loss: 217.04571706771463
# Scene: 14.0, Sequence: 22.0, Frame: 11, Seq Loss: 208.13065182212685
# Scene: 14.0, Sequence: 23.0, Frame: 11, Seq Loss: 218.57736964277723
# Scene: 14.0, Sequence: 24.0, Frame: 11, Seq Loss: 167.72688082933084
# Scene: 14.0, Sequence: 25.0, Frame: 11, Seq Loss: 173.56839410892871
# Scene: 14.0, Sequence: 26.0, Frame: 11, Seq Loss: 220.16424564427052
# Scene: 15.0, Sequence: 1.0, Frame: 11, Seq Loss: 238.95636518896146
# Scene: 15.0, Sequence: 2.0, Frame: 11, Seq Loss: 202.720754911832
# Scene: 15.0, Sequence: 3.0, Frame: 11, Seq Loss: 200.70262587925276
# Scene: 15.0, Sequence: 4.0, Frame: 11, Seq Loss: 210.7991040713843
# Scene: 15.0, Sequence: 5.0, Frame: 11, Seq Loss: 215.63675863899493
# Scene: 15.0, Sequence: 6.0, Frame: 11, Seq Loss: 215.1465286659228
# Scene: 15.0, Sequence: 7.0, Frame: 11, Seq Loss: 224.90489834966883
# Scene: 15.0, Sequence: 8.0, Frame: 11, Seq Loss: 221.8337229879201
# Scene: 15.0, Sequence: 9.0, Frame: 11, Seq Loss: 209.92550224605748
# Scene: 15.0, Sequence: 10.0, Frame: 11, Seq Loss: 214.54791085015694
# Scene: 15.0, Sequence: 11.0, Frame: 11, Seq Loss: 210.16588013184412
# Scene: 15.0, Sequence: 12.0, Frame: 11, Seq Loss: 208.09470517911387
# Scene: 15.0, Sequence: 13.0, Frame: 11, Seq Loss: 210.67474268786583
# Scene: 15.0, Sequence: 14.0, Frame: 11, Seq Loss: 211.94072203437884
# Scene: 15.0, Sequence: 15.0, Frame: 11, Seq Loss: 209.0807668189212
# Scene: 15.0, Sequence: 16.0, Frame: 11, Seq Loss: 209.077600803671
# Scene: 15.0, Sequence: 17.0, Frame: 11, Seq Loss: 217.09584538686954
# Scene: 15.0, Sequence: 18.0, Frame: 11, Seq Loss: 223.32423299450403
# Scene: 15.0, Sequence: 19.0, Frame: 11, Seq Loss: 220.73287923308482
# Scene: 15.0, Sequence: 20.0, Frame: 11, Seq Loss: 224.71066307737817
# Scene: 15.0, Sequence: 21.0, Frame: 11, Seq Loss: 210.02243149338426
# Scene: 15.0, Sequence: 22.0, Frame: 11, Seq Loss: 216.76752139395407
# Scene: 15.0, Sequence: 23.0, Frame: 11, Seq Loss: 213.32155211134145
# Scene: 15.0, Sequence: 24.0, Frame: 11, Seq Loss: 216.01319581429271
# Scene: 15.0, Sequence: 25.0, Frame: 11, Seq Loss: 203.84439161800145
# Scene: 15.0, Sequence: 26.0, Frame: 11, Seq Loss: 220.0598647769238
# Scene: 16.0, Sequence: 1.0, Frame: 11, Seq Loss: 220.58008622303637
# Scene: 16.0, Sequence: 2.0, Frame: 11, Seq Loss: 219.016759400027
# Scene: 16.0, Sequence: 3.0, Frame: 11, Seq Loss: 216.11128868271183
# Scene: 16.0, Sequence: 4.0, Frame: 11, Seq Loss: 214.68916776169246
# Scene: 16.0, Sequence: 5.0, Frame: 11, Seq Loss: 213.58563241724184
# Scene: 16.0, Sequence: 6.0, Frame: 11, Seq Loss: 216.45415246923739
# Scene: 16.0, Sequence: 7.0, Frame: 11, Seq Loss: 196.94019478797273
# Scene: 16.0, Sequence: 8.0, Frame: 11, Seq Loss: 220.50894886830307
# Scene: 16.0, Sequence: 9.0, Frame: 11, Seq Loss: 222.2954820152261
# Scene: 16.0, Sequence: 10.0, Frame: 11, Seq Loss: 221.8987354088754
# Scene: 16.0, Sequence: 11.0, Frame: 11, Seq Loss: 220.66629757469877
# Scene: 16.0, Sequence: 12.0, Frame: 11, Seq Loss: 233.86963632886773
# Scene: 16.0, Sequence: 13.0, Frame: 11, Seq Loss: 206.7329228665746
# Scene: 16.0, Sequence: 14.0, Frame: 11, Seq Loss: 214.52908836439912
# Scene: 16.0, Sequence: 15.0, Frame: 11, Seq Loss: 213.93872672738888
# Scene: 16.0, Sequence: 16.0, Frame: 11, Seq Loss: 213.45507089583305
# Scene: 16.0, Sequence: 17.0, Frame: 11, Seq Loss: 215.72619968712723
# Scene: 16.0, Sequence: 18.0, Frame: 11, Seq Loss: 212.73542095329339
# Scene: 16.0, Sequence: 19.0, Frame: 11, Seq Loss: 210.03016852859284
# Scene: 16.0, Sequence: 20.0, Frame: 11, Seq Loss: 224.4794488382155
# Scene: 16.0, Sequence: 21.0, Frame: 11, Seq Loss: 204.08367597625625
# Scene: 16.0, Sequence: 22.0, Frame: 11, Seq Loss: 202.42756018811968
# Scene: 16.0, Sequence: 23.0, Frame: 11, Seq Loss: 199.70166733222902
# Scene: 16.0, Sequence: 24.0, Frame: 11, Seq Loss: 197.28588023244396
# Scene: 16.0, Sequence: 25.0, Frame: 11, Seq Loss: 196.98312606387663
# Scene: 16.0, Sequence: 26.0, Frame: 11, Seq Loss: 197.6226477633457
# Scene: 17.0, Sequence: 1.0, Frame: 11, Seq Loss: 192.7662395221599
# Scene: 17.0, Sequence: 2.0, Frame: 11, Seq Loss: 263.44716471479614
# Scene: 17.0, Sequence: 3.0, Frame: 11, Seq Loss: 194.65050108644104
# Scene: 17.0, Sequence: 4.0, Frame: 11, Seq Loss: 203.84188175721488
# Scene: 17.0, Sequence: 5.0, Frame: 11, Seq Loss: 206.2097910272891
# Scene: 17.0, Sequence: 6.0, Frame: 11, Seq Loss: 209.98191421763454
# Scene: 17.0, Sequence: 7.0, Frame: 11, Seq Loss: 197.16653351092378
# Scene: 17.0, Sequence: 8.0, Frame: 11, Seq Loss: 199.82037896588133
# Scene: 17.0, Sequence: 9.0, Frame: 11, Seq Loss: 197.0615001227032
# Scene: 17.0, Sequence: 10.0, Frame: 11, Seq Loss: 198.49442380875104
# Scene: 17.0, Sequence: 11.0, Frame: 11, Seq Loss: 195.15602535883374
# Scene: 17.0, Sequence: 12.0, Frame: 11, Seq Loss: 202.44715372888413
# Scene: 17.0, Sequence: 13.0, Frame: 11, Seq Loss: 201.4454799463436
# Scene: 17.0, Sequence: 14.0, Frame: 11, Seq Loss: 194.7536252242918
# Scene: 17.0, Sequence: 15.0, Frame: 11, Seq Loss: 168.27970142291474
# Scene: 17.0, Sequence: 16.0, Frame: 11, Seq Loss: 186.11375275205674
# Scene: 17.0, Sequence: 17.0, Frame: 11, Seq Loss: 195.94345661533424
# Scene: 17.0, Sequence: 18.0, Frame: 11, Seq Loss: 196.31404193842303
# Scene: 17.0, Sequence: 19.0, Frame: 11, Seq Loss: 214.10575995984803
# Scene: 17.0, Sequence: 20.0, Frame: 11, Seq Loss: 218.34422578562743
# Scene: 17.0, Sequence: 21.0, Frame: 11, Seq Loss: 196.96532149406858
# Scene: 17.0, Sequence: 22.0, Frame: 11, Seq Loss: 238.9496042524588
# Scene: 17.0, Sequence: 23.0, Frame: 11, Seq Loss: 218.00765843014284
# Scene: 17.0, Sequence: 24.0, Frame: 11, Seq Loss: 207.70640302434964
# Scene: 17.0, Sequence: 25.0, Frame: 11, Seq Loss: 148.88853001023836
# Scene: 17.0, Sequence: 26.0, Frame: 11, Seq Loss: 179.9323296109993
# Scene: 18.0, Sequence: 1.0, Frame: 11, Seq Loss: 194.84146883053617
# Scene: 18.0, Sequence: 2.0, Frame: 11, Seq Loss: 209.44832336422496
# Scene: 18.0, Sequence: 3.0, Frame: 11, Seq Loss: 198.75350672119026
# Scene: 18.0, Sequence: 4.0, Frame: 11, Seq Loss: 195.96175615024652
# Scene: 18.0, Sequence: 5.0, Frame: 11, Seq Loss: 240.77072352148326
# Scene: 18.0, Sequence: 6.0, Frame: 11, Seq Loss: 229.77276522809183
# Scene: 18.0, Sequence: 7.0, Frame: 11, Seq Loss: 213.88407597011422
# Scene: 18.0, Sequence: 8.0, Frame: 11, Seq Loss: 198.75066746740723
# Scene: 18.0, Sequence: 9.0, Frame: 11, Seq Loss: 195.7102256012554
# Scene: 18.0, Sequence: 10.0, Frame: 11, Seq Loss: 199.20249703105983
# Scene: 18.0, Sequence: 11.0, Frame: 11, Seq Loss: 201.38776808255392
# Scene: 18.0, Sequence: 12.0, Frame: 11, Seq Loss: 208.71053541917016
# Scene: 18.0, Sequence: 13.0, Frame: 11, Seq Loss: 219.20478861747506
# Scene: 18.0, Sequence: 14.0, Frame: 11, Seq Loss: 202.56150169248016
# Scene: 18.0, Sequence: 15.0, Frame: 11, Seq Loss: 209.577636321097
# Scene: 18.0, Sequence: 16.0, Frame: 11, Seq Loss: 209.65492423256893
# Scene: 18.0, Sequence: 17.0, Frame: 11, Seq Loss: 217.10370721343003
# Scene: 18.0, Sequence: 18.0, Frame: 11, Seq Loss: 227.3514215275886
# Scene: 18.0, Sequence: 19.0, Frame: 11, Seq Loss: 203.16450317148394
# Scene: 18.0, Sequence: 20.0, Frame: 11, Seq Loss: 213.68248393914538
# Scene: 18.0, Sequence: 21.0, Frame: 11, Seq Loss: 246.16319735907675
# Scene: 18.0, Sequence: 22.0, Frame: 11, Seq Loss: 229.15489501667497
# Scene: 18.0, Sequence: 23.0, Frame: 11, Seq Loss: 211.51705418575688
# Scene: 18.0, Sequence: 24.0, Frame: 11, Seq Loss: 237.21152466721944
# Scene: 18.0, Sequence: 25.0, Frame: 11, Seq Loss: 234.0506185834779
# Scene: 18.0, Sequence: 26.0, Frame: 11, Seq Loss: 208.9121933276586
# Scene: 19.0, Sequence: 1.0, Frame: 11, Seq Loss: 137.3816175770649
# Scene: 19.0, Sequence: 2.0, Frame: 11, Seq Loss: 137.04645102699837
# Scene: 19.0, Sequence: 3.0, Frame: 11, Seq Loss: 154.81425585954918
# Scene: 19.0, Sequence: 4.0, Frame: 11, Seq Loss: 169.50281506120913
# Scene: 19.0, Sequence: 5.0, Frame: 11, Seq Loss: 173.79634827692115
# Scene: 19.0, Sequence: 6.0, Frame: 11, Seq Loss: 208.94533025841318
# Scene: 19.0, Sequence: 7.0, Frame: 11, Seq Loss: 200.85988241540906
# Scene: 19.0, Sequence: 8.0, Frame: 11, Seq Loss: 207.20491224959795
# Scene: 19.0, Sequence: 9.0, Frame: 11, Seq Loss: 210.21301289150216
# Scene: 19.0, Sequence: 10.0, Frame: 11, Seq Loss: 198.72549257108068
# Scene: 19.0, Sequence: 11.0, Frame: 11, Seq Loss: 193.58697543788284
# Scene: 19.0, Sequence: 12.0, Frame: 11, Seq Loss: 166.63876486863842
# Scene: 19.0, Sequence: 13.0, Frame: 11, Seq Loss: 151.7247387398078
# Scene: 19.0, Sequence: 14.0, Frame: 11, Seq Loss: 166.44668126810933
# Scene: 19.0, Sequence: 15.0, Frame: 11, Seq Loss: 223.4844217550093
# Scene: 19.0, Sequence: 16.0, Frame: 11, Seq Loss: 175.9142261861578
# Scene: 19.0, Sequence: 17.0, Frame: 11, Seq Loss: 197.53589030029997
# Scene: 19.0, Sequence: 18.0, Frame: 11, Seq Loss: 187.12226167260565
# Scene: 19.0, Sequence: 19.0, Frame: 11, Seq Loss: 163.68875051493075
# Scene: 19.0, Sequence: 20.0, Frame: 11, Seq Loss: 217.67874283370426
# Scene: 19.0, Sequence: 21.0, Frame: 11, Seq Loss: 247.84441516632262
# Scene: 19.0, Sequence: 22.0, Frame: 11, Seq Loss: 196.5866778882646
# Scene: 19.0, Sequence: 23.0, Frame: 11, Seq Loss: 204.051332189726
# Scene: 19.0, Sequence: 24.0, Frame: 11, Seq Loss: 202.53708569485707
# Scene: 19.0, Sequence: 25.0, Frame: 11, Seq Loss: 194.35203799291475
# Scene: 19.0, Sequence: 26.0, Frame: 11, Seq Loss: 194.6224182649837

# %%
print("1s: {}, 2s: {}, 3s: {}, 4s: {}".format(np.mean(valLoss1), np.mean(valLoss2), np.mean(valLoss3), np.mean(valLoss4)))
# Out:
# 1s: 209.80377651856017, 2s: 209.80377651856017, 3s: 209.80377651856017, 4s: 209.80377651856017

# %%
print("HitPreds: {}, TotalPreds: {}, Hit Rate: {}".format(hitPreds, totalPreds, hitPreds / totalPreds))
# Out:
# HitPreds: 0, TotalPreds: 1664, Hit Rate: 0.0
