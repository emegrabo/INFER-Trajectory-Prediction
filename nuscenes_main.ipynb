# %%
import os
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
import math
import time

from Nuscenes_dataset_test import NuscenesDatasetTest
from Model import EnDeWithPooling, EnDeConvLSTM_ws, SkipLSTMEnDe
from torchvision import transforms
from PIL import Image

# %%
def saveTransformedImages(imageTensor):
    to_pil = torchvision.transforms.ToPILImage()
    im = to_pil(imageTensor)
    mn, mx = np.min(im), np.max(im)
    im = (im - mn) / (mx - mn)
    print(im)
    plt.imshow(im, cmap='gray')
    plt.show()

# %%
def plotTrajectory(xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti, seqLen, im_path, numFrames=None):
    fig = plt.figure(figsize=(8, 8))
    plt.plot(yValsGT, xValsGT, c='r', label='Ground Truth')
    plt.plot(yValsPred, xValsPred, c='g', label='Prediction')
    plt.plot(yValsPredMulti, xValsPredMulti, c='b', label='Multimodal Prediction', alpha=0.8)
    axes = plt.gca()
    axes.set_xlim([1, 512])
    axes.set_ylim([1, 512])
    plt.xlabel('X-Axis')
    plt.ylabel('Y-Axis')
    plt.legend(loc='upper right')
    if numFrames == None:
        plt.title('Trajectory')
    else:
        plot_title = 'Trajectory (' + str(numFrames // 10 - 2) + "s)"
        plt.title(plot_title)
    plt.savefig(im_path)
    plt.close()

# %%
def heatmapAccuracy(outputMap, labelMap, thr=1.5):
    pred = np.unravel_index(outputMap.argmax(), outputMap.shape)
    gt = np.unravel_index(labelMap.argmax(), labelMap.shape)

    dist = math.sqrt((pred[0] - gt[0]) ** 2 + (pred[1] - gt[1]) ** 2)
    if dist <= thr:
        return 1, dist, (pred[0], pred[1]), (gt[0], gt[1])
    return 0, dist, (pred[0], pred[1]), (gt[0], gt[1])

# %%
def largest_indices(ary, n):
    """Returns the n largest indices from a numpy array."""
    flat = ary.flatten()
    indices = np.argpartition(flat, -n)[-n:]
    indices = indices[np.argsort(-flat[indices])]
    return np.unravel_index(indices, ary.shape)

# %%
def multiAccuracy(outputMap, labelMap, topK=5):
    pred = largest_indices(outputMap, topK)
    gt = np.unravel_index(labelMap.argmax(), labelMap.shape)
    dist_arr = []
    for i in range(len(pred[0])):
        dist = math.sqrt((pred[0][i] - gt[0]) ** 2 + (pred[1][i] - gt[1]) ** 2)
        dist_arr.append(dist)
    
    min_val = np.min(dist_arr)
    min_idx = np.argmin(dist_arr)
    within_radius = 0
    if min_val <= 4:
        within_radius = 1
    return 0, min_val, (pred[0][min_idx], pred[1][min_idx]), (gt[0], gt[1]), within_radius

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %% [markdown]
# ### Set Cross Validation No

# %%
checkpoint_path = "/home/sas115/trajectory_prediction_INFER-master/ablation_cache_nuscenes/skipLSTM/split-0/checkpoint_future_best.tar"

# %%
# Choose the corresponding model for each split
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-0", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-1", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-2", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-3", "checkpoint_future.tar")
# checkpoint_path = os.path.join(repo_dir, "models", "kitti-main", "cv-4", "checkpoint_future.tar")

# %%
checkpoint = torch.load(checkpoint_path)
model = SkipLSTMEnDe(activation="relu", initType="default", numChannels=5, imageHeight=256, imageWidth=256, batchnorm=False, softmax=False)
model.load_state_dict(checkpoint["model_state_dict"])
model = model.cuda()
model.convlstm = model.convlstm.cuda()

# %%
# data_dir = "/home/fbd/rrc/submission/INFER-datasets/kitti"
# val_dir = os.path.join(data_dir, "final-validation", "test" + str(cv_num) + ".csv")
# val_dataset = KittiDataset(data_dir, height=256, width=256, train=False, infoPath=val_dir, augmentation=False, groundTruth=True)

# %%
data_dir = "/home/sas115/trajectory_prediction_INFER-master/nuScenes_project_dataset_test"
val_dataset = NuscenesDatasetTest(data_dir, height=256, width=256,)

# %% [markdown]
# ### Future Prediction (Final, Validation)

# %%
upsample_512 = torch.nn.Upsample(scale_factor=2, mode='bilinear')
labelTransform = transforms.Compose([
    transforms.ToTensor()
])

valLoss1, valLoss2, valLoss3, valLoss4, valLoss = [], [], [], [], []
topK = 5
totalPreds = 0
hitPreds = 0

# %%
debug, prevOut, state = True, None, None
prevChannels = None
xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti = [], [], [], [], [], []
seqLoss, seqVals = [], []
seqNum, seqLen = 0, 0

start_time = time.time()
model.eval()
new_seq_loss = []

for i in range(len(val_dataset)):
    grid, sceneNum, seqNum, frame_num, endOfSequence = val_dataset[i]
    grid = grid.type(torch.cuda.FloatTensor)
    
    # The Last Channel is the target frame and first n - 1 are source frames
    inp = grid[:-1, :].unsqueeze(0).to(device)
    currLabel = grid[-1:, :].unsqueeze(0).to(device)
    
    if frame_num < 4:
        prevChannels = inp

    if frame_num >= 4:
        new_inp = inp.clone().squeeze(0)
        mn, mx = torch.min(prevOut), torch.max(prevOut)
        prevOut = (prevOut - mn) / (mx - mn)
        new_inp[0] = prevOut
        new_inp[4] = prevChannels[0, 4, :, :]        
        inp = new_inp.unsqueeze(0).cuda()

    # Forward the input and obtain the result
    out = model.forward(inp, state)
    state = (model.h, model.c, model.h1, model.c1, model.h2, model.c2)
    currOutputMap = out.clone()
    newOutputMap = upsample_512(currOutputMap)
    
    nextTargetTensor = grid[5,:,:]
    
    prevOut = currOutputMap.detach().cpu().squeeze(0).squeeze(0)
    currOutputMap = currOutputMap.detach().cpu().numpy().squeeze(0).squeeze(0)
    currLabel = currLabel.detach().cpu().numpy().squeeze(0).squeeze(0)
    
    # Upsampled outputs and inputs
#     currOutputMap1 = newOutputMap.detach().cpu().numpy().squeeze(0).squeeze(0)
#     currLabel1 = nextTargetTensor_upsampled.detach().cpu().numpy().squeeze(0).squeeze(0)
    
    _, dist1, predCoordinates1, gtCoordinates1 = heatmapAccuracy(currOutputMap, currLabel)
    _, dist2, predCoordinates2, gtCoordinates2, within_radius = multiAccuracy(currOutputMap, currLabel, topK=topK)
    
    if frame_num >= 4:
        seqLoss.append(dist2)
        new_seq_loss.append([dist2])        
        totalPreds += 1
        if within_radius == 1:
            hitPreds += 1
            
    
    seqLen += 1
    xValsGT.append(gtCoordinates1[0])
    yValsGT.append(gtCoordinates1[1])
    xValsPred.append(predCoordinates1[0])
    yValsPred.append(predCoordinates1[1])
    xValsPredMulti.append(predCoordinates2[0])
    yValsPredMulti.append(predCoordinates2[1])
    
    #import pdb; pdb.set_trace()
    if endOfSequence:
        seqVals.append(seqLen)
        xValsGT, yValsGT, xValsPred, yValsPred, xValsPredMulti, yValsPredMulti = [], [], [], [], [], []
        seqNum +=1
        state = None
        valLoss.append(np.mean(seqLoss))
        valLoss1.append(np.mean(seqLoss[:2]))
        valLoss2.append(np.mean(seqLoss[:4]))
        valLoss3.append(np.mean(seqLoss[:6]))
        valLoss4.append(np.mean(seqLoss[:8]))
        print("Scene: {}, Sequence: {}, Frame: {}, Seq Loss: {}".format(sceneNum, seqNum, frame_num, np.mean(seqLoss)))
        #import pdb; pdb.set_trace()
        seqLoss = []

end_time = time.time()
# Out:
# Scene: 44.0, Sequence: 1.0, Frame: 11, Seq Loss: 18.863141051654853
# Scene: 44.0, Sequence: 2.0, Frame: 11, Seq Loss: 17.051666480941222
# Scene: 44.0, Sequence: 3.0, Frame: 11, Seq Loss: 13.065673497156007
# Scene: 44.0, Sequence: 4.0, Frame: 11, Seq Loss: 18.870043407738603
# Scene: 44.0, Sequence: 5.0, Frame: 11, Seq Loss: 17.10087016907076
# Scene: 44.0, Sequence: 6.0, Frame: 11, Seq Loss: 24.861222851055068
# Scene: 44.0, Sequence: 7.0, Frame: 11, Seq Loss: 28.187009557687553
# Scene: 44.0, Sequence: 8.0, Frame: 11, Seq Loss: 23.88066000181337
# Scene: 44.0, Sequence: 9.0, Frame: 11, Seq Loss: 20.33354319797276
# Scene: 44.0, Sequence: 10.0, Frame: 11, Seq Loss: 28.88684620209215
# Scene: 44.0, Sequence: 11.0, Frame: 11, Seq Loss: 24.038254719523742
# Scene: 44.0, Sequence: 12.0, Frame: 11, Seq Loss: 29.07378766858003
# Scene: 44.0, Sequence: 13.0, Frame: 11, Seq Loss: 29.242405934600594
# Scene: 44.0, Sequence: 14.0, Frame: 11, Seq Loss: 24.46201954806481
# Scene: 44.0, Sequence: 15.0, Frame: 11, Seq Loss: 37.87362584501312
# Scene: 44.0, Sequence: 16.0, Frame: 11, Seq Loss: 53.78121725989321
# Scene: 44.0, Sequence: 17.0, Frame: 11, Seq Loss: 31.440836913552744
# Scene: 44.0, Sequence: 18.0, Frame: 11, Seq Loss: 31.031973932710443
# Scene: 44.0, Sequence: 19.0, Frame: 11, Seq Loss: 62.953935831626644
# Scene: 44.0, Sequence: 20.0, Frame: 11, Seq Loss: 53.870627272082956
# Scene: 44.0, Sequence: 21.0, Frame: 11, Seq Loss: 20.024416691379283
# Scene: 44.0, Sequence: 22.0, Frame: 11, Seq Loss: 23.261560671964958
# Scene: 44.0, Sequence: 23.0, Frame: 11, Seq Loss: 19.908314407423156
# Scene: 44.0, Sequence: 24.0, Frame: 11, Seq Loss: 88.0408292523184
# Scene: 44.0, Sequence: 25.0, Frame: 11, Seq Loss: 44.94869782210963
# Scene: 44.0, Sequence: 26.0, Frame: 11, Seq Loss: 52.97454779355523
# Scene: 45.0, Sequence: 1.0, Frame: 11, Seq Loss: 18.099858524035458
# Scene: 45.0, Sequence: 2.0, Frame: 11, Seq Loss: 14.532706172706567
# Scene: 45.0, Sequence: 3.0, Frame: 11, Seq Loss: 8.647508927531367
# Scene: 45.0, Sequence: 4.0, Frame: 11, Seq Loss: 8.745663541882909
# Scene: 45.0, Sequence: 5.0, Frame: 11, Seq Loss: 14.907492432706318
# Scene: 45.0, Sequence: 6.0, Frame: 11, Seq Loss: 16.18185361454108
# Scene: 45.0, Sequence: 7.0, Frame: 11, Seq Loss: 23.313872345494516
# Scene: 45.0, Sequence: 8.0, Frame: 11, Seq Loss: 19.75326804207341
# Scene: 45.0, Sequence: 9.0, Frame: 11, Seq Loss: 20.868244567254273
# Scene: 45.0, Sequence: 10.0, Frame: 11, Seq Loss: 26.615363625129618
# Scene: 45.0, Sequence: 11.0, Frame: 11, Seq Loss: 25.550042834544843
# Scene: 45.0, Sequence: 12.0, Frame: 11, Seq Loss: 19.44654038856357
# Scene: 45.0, Sequence: 13.0, Frame: 11, Seq Loss: 19.90806956972748
# Scene: 45.0, Sequence: 14.0, Frame: 11, Seq Loss: 18.35068452644302
# Scene: 45.0, Sequence: 15.0, Frame: 11, Seq Loss: 21.21079752354649
# Scene: 45.0, Sequence: 16.0, Frame: 11, Seq Loss: 19.530267187053497
# Scene: 45.0, Sequence: 17.0, Frame: 11, Seq Loss: 20.274868936003344
# Scene: 45.0, Sequence: 18.0, Frame: 11, Seq Loss: 9.060623231929767
# Scene: 45.0, Sequence: 19.0, Frame: 11, Seq Loss: 27.307209387542677
# Scene: 45.0, Sequence: 20.0, Frame: 11, Seq Loss: 14.588339707777568
# Scene: 45.0, Sequence: 21.0, Frame: 11, Seq Loss: 14.95622165046415
# Scene: 45.0, Sequence: 22.0, Frame: 11, Seq Loss: 7.97308725226365
# Scene: 45.0, Sequence: 23.0, Frame: 11, Seq Loss: 6.9039548356136855
# Scene: 45.0, Sequence: 24.0, Frame: 11, Seq Loss: 2.732804352645269
# Scene: 45.0, Sequence: 25.0, Frame: 11, Seq Loss: 7.318496562628854
# Scene: 45.0, Sequence: 26.0, Frame: 11, Seq Loss: 10.422277069178655
# Scene: 46.0, Sequence: 1.0, Frame: 11, Seq Loss: 14.08912740271094
# Scene: 46.0, Sequence: 2.0, Frame: 11, Seq Loss: 21.94167148060447
# Scene: 46.0, Sequence: 3.0, Frame: 11, Seq Loss: 6.897530695110768
# Scene: 46.0, Sequence: 4.0, Frame: 11, Seq Loss: 6.218081542984821
# Scene: 46.0, Sequence: 5.0, Frame: 11, Seq Loss: 5.487802363405741
# Scene: 46.0, Sequence: 6.0, Frame: 11, Seq Loss: 6.433801212557199
# Scene: 46.0, Sequence: 7.0, Frame: 11, Seq Loss: 3.4057764064044154
# Scene: 46.0, Sequence: 8.0, Frame: 11, Seq Loss: 7.020159657736417
# Scene: 46.0, Sequence: 9.0, Frame: 11, Seq Loss: 7.549429299735285
# Scene: 46.0, Sequence: 10.0, Frame: 11, Seq Loss: 2.235476532860451
# Scene: 46.0, Sequence: 11.0, Frame: 11, Seq Loss: 1.9542197524582479
# Scene: 46.0, Sequence: 12.0, Frame: 11, Seq Loss: 8.003366622655717
# Scene: 46.0, Sequence: 13.0, Frame: 11, Seq Loss: 7.924393039069608
# Scene: 46.0, Sequence: 14.0, Frame: 11, Seq Loss: 7.548000316840781
# Scene: 46.0, Sequence: 15.0, Frame: 11, Seq Loss: 22.80952727636162
# Scene: 46.0, Sequence: 16.0, Frame: 11, Seq Loss: 44.62001319039755
# Scene: 46.0, Sequence: 17.0, Frame: 11, Seq Loss: 29.621188936119136
# Scene: 46.0, Sequence: 18.0, Frame: 11, Seq Loss: 22.727962895100635
# Scene: 46.0, Sequence: 19.0, Frame: 11, Seq Loss: 29.024293082285897
# Scene: 46.0, Sequence: 20.0, Frame: 11, Seq Loss: 26.038421758736646
# Scene: 46.0, Sequence: 21.0, Frame: 11, Seq Loss: 54.745689096341835
# Scene: 46.0, Sequence: 22.0, Frame: 11, Seq Loss: 22.802215126945693
# Scene: 46.0, Sequence: 23.0, Frame: 11, Seq Loss: 55.01654470534554
# Scene: 46.0, Sequence: 24.0, Frame: 11, Seq Loss: 70.09717487205552
# Scene: 46.0, Sequence: 25.0, Frame: 11, Seq Loss: 76.92258887710251
# Scene: 46.0, Sequence: 26.0, Frame: 11, Seq Loss: 23.306470370215823
# Scene: 47.0, Sequence: 1.0, Frame: 11, Seq Loss: 9.524643333589902
# Scene: 47.0, Sequence: 2.0, Frame: 11, Seq Loss: 10.410689155085944
# Scene: 47.0, Sequence: 3.0, Frame: 11, Seq Loss: 4.0329780443524665
# Scene: 47.0, Sequence: 4.0, Frame: 11, Seq Loss: 5.929260968447564
# Scene: 47.0, Sequence: 5.0, Frame: 11, Seq Loss: 3.000176046435593
# Scene: 47.0, Sequence: 6.0, Frame: 11, Seq Loss: 2.182773143051522
# Scene: 47.0, Sequence: 7.0, Frame: 11, Seq Loss: 1.4571067811865475
# Scene: 47.0, Sequence: 8.0, Frame: 11, Seq Loss: 1.7140674110214293
# Scene: 47.0, Sequence: 9.0, Frame: 11, Seq Loss: 1.8952847075210475
# Scene: 47.0, Sequence: 10.0, Frame: 11, Seq Loss: 2.316799212912266
# Scene: 47.0, Sequence: 11.0, Frame: 11, Seq Loss: 5.65711543589281
# Scene: 47.0, Sequence: 12.0, Frame: 11, Seq Loss: 1.375
# Scene: 47.0, Sequence: 13.0, Frame: 11, Seq Loss: 4.6767766952966365
# Scene: 47.0, Sequence: 14.0, Frame: 11, Seq Loss: 8.460925765359242
# Scene: 47.0, Sequence: 15.0, Frame: 11, Seq Loss: 18.11253259804188
# Scene: 47.0, Sequence: 16.0, Frame: 11, Seq Loss: 10.365310440602695
# Scene: 47.0, Sequence: 17.0, Frame: 11, Seq Loss: 19.173711680143843
# Scene: 47.0, Sequence: 18.0, Frame: 11, Seq Loss: 18.162879242718187
# Scene: 47.0, Sequence: 19.0, Frame: 11, Seq Loss: 22.743109392306994
# Scene: 47.0, Sequence: 20.0, Frame: 11, Seq Loss: 20.953119349128677
# Scene: 47.0, Sequence: 21.0, Frame: 11, Seq Loss: 37.835879740979976
# Scene: 47.0, Sequence: 22.0, Frame: 11, Seq Loss: 37.15824031352369
# Scene: 47.0, Sequence: 23.0, Frame: 11, Seq Loss: 40.40142630775388
# Scene: 47.0, Sequence: 24.0, Frame: 11, Seq Loss: 43.791624312438024
# Scene: 47.0, Sequence: 25.0, Frame: 11, Seq Loss: 27.700094339704513
# Scene: 47.0, Sequence: 26.0, Frame: 11, Seq Loss: 16.491368413867235
# Scene: 48.0, Sequence: 1.0, Frame: 11, Seq Loss: 10.71998711790132
# Scene: 48.0, Sequence: 2.0, Frame: 11, Seq Loss: 9.011205902900182
# Scene: 48.0, Sequence: 3.0, Frame: 11, Seq Loss: 8.558525464156435
# Scene: 48.0, Sequence: 4.0, Frame: 11, Seq Loss: 5.078627066676104
# Scene: 48.0, Sequence: 5.0, Frame: 11, Seq Loss: 2.9562851924841107
# Scene: 48.0, Sequence: 6.0, Frame: 11, Seq Loss: 4.478881767405279
# Scene: 48.0, Sequence: 7.0, Frame: 11, Seq Loss: 6.625
# Scene: 48.0, Sequence: 8.0, Frame: 11, Seq Loss: 2.2795084971874737
# Scene: 48.0, Sequence: 9.0, Frame: 11, Seq Loss: 5.2682633965639925
# Scene: 48.0, Sequence: 10.0, Frame: 11, Seq Loss: 1.926776695296637
# Scene: 48.0, Sequence: 11.0, Frame: 11, Seq Loss: 3.7216733956863184
# Scene: 48.0, Sequence: 12.0, Frame: 11, Seq Loss: 3.9828409671268683
# Scene: 48.0, Sequence: 13.0, Frame: 11, Seq Loss: 4.13251059871976
# Scene: 48.0, Sequence: 14.0, Frame: 11, Seq Loss: 6.130670127148408
# Scene: 48.0, Sequence: 15.0, Frame: 11, Seq Loss: 9.921900086740688
# Scene: 48.0, Sequence: 16.0, Frame: 11, Seq Loss: 13.245035114235357
# Scene: 48.0, Sequence: 17.0, Frame: 11, Seq Loss: 8.538351265604597
# Scene: 48.0, Sequence: 18.0, Frame: 11, Seq Loss: 11.713130071595804
# Scene: 48.0, Sequence: 19.0, Frame: 11, Seq Loss: 9.943978831174121
# Scene: 48.0, Sequence: 20.0, Frame: 11, Seq Loss: 18.48655106339094
# Scene: 48.0, Sequence: 21.0, Frame: 11, Seq Loss: 8.485792129122839
# Scene: 48.0, Sequence: 22.0, Frame: 11, Seq Loss: 8.330818966704374
# Scene: 48.0, Sequence: 23.0, Frame: 11, Seq Loss: 11.953490677190317
# Scene: 48.0, Sequence: 24.0, Frame: 11, Seq Loss: 17.022283788318944
# Scene: 48.0, Sequence: 25.0, Frame: 11, Seq Loss: 25.718979425183264
# Scene: 48.0, Sequence: 26.0, Frame: 11, Seq Loss: 14.394732339738983
# Scene: 49.0, Sequence: 1.0, Frame: 11, Seq Loss: 14.987533170640413
# Scene: 49.0, Sequence: 2.0, Frame: 11, Seq Loss: 10.804497871008717
# Scene: 49.0, Sequence: 3.0, Frame: 11, Seq Loss: 6.5573584813073476
# Scene: 49.0, Sequence: 4.0, Frame: 11, Seq Loss: 4.700535882715187
# Scene: 49.0, Sequence: 5.0, Frame: 11, Seq Loss: 3.686186517852847
# Scene: 49.0, Sequence: 6.0, Frame: 11, Seq Loss: 3.11554772290775
# Scene: 49.0, Sequence: 7.0, Frame: 11, Seq Loss: 5.103553390593273
# Scene: 49.0, Sequence: 8.0, Frame: 11, Seq Loss: 16.46665878243399
# Scene: 49.0, Sequence: 9.0, Frame: 11, Seq Loss: 10.708909556245457
# Scene: 49.0, Sequence: 10.0, Frame: 11, Seq Loss: 11.923966119094182
# Scene: 49.0, Sequence: 11.0, Frame: 11, Seq Loss: 11.444186524991261
# Scene: 49.0, Sequence: 12.0, Frame: 11, Seq Loss: 20.958181662549777
# Scene: 49.0, Sequence: 13.0, Frame: 11, Seq Loss: 31.087782278913913
# Scene: 49.0, Sequence: 14.0, Frame: 11, Seq Loss: 21.91686122572347
# Scene: 49.0, Sequence: 15.0, Frame: 11, Seq Loss: 18.2354508007122
# Scene: 49.0, Sequence: 16.0, Frame: 11, Seq Loss: 18.691320261872516
# Scene: 49.0, Sequence: 17.0, Frame: 11, Seq Loss: 16.593311302743487
# Scene: 49.0, Sequence: 18.0, Frame: 11, Seq Loss: 15.280301782863354
# Scene: 49.0, Sequence: 19.0, Frame: 11, Seq Loss: 6.754770132907032
# Scene: 49.0, Sequence: 20.0, Frame: 11, Seq Loss: 9.037754026248678
# Scene: 49.0, Sequence: 21.0, Frame: 11, Seq Loss: 6.242220545972735
# Scene: 49.0, Sequence: 22.0, Frame: 11, Seq Loss: 8.988627968328501
# Scene: 49.0, Sequence: 23.0, Frame: 11, Seq Loss: 16.099432622124073
# Scene: 49.0, Sequence: 24.0, Frame: 11, Seq Loss: 11.01473816607653
# Scene: 49.0, Sequence: 25.0, Frame: 11, Seq Loss: 17.187482848570436
# Scene: 49.0, Sequence: 26.0, Frame: 11, Seq Loss: 12.205049406691275
# Scene: 50.0, Sequence: 1.0, Frame: 11, Seq Loss: 25.118128134800827
# Scene: 50.0, Sequence: 2.0, Frame: 11, Seq Loss: 30.645897664070503
# Scene: 50.0, Sequence: 3.0, Frame: 11, Seq Loss: 32.36187273469493
# Scene: 50.0, Sequence: 4.0, Frame: 11, Seq Loss: 56.715463750525494
# Scene: 50.0, Sequence: 5.0, Frame: 11, Seq Loss: 21.069268271673884
# Scene: 50.0, Sequence: 6.0, Frame: 11, Seq Loss: 20.228752088265637
# Scene: 50.0, Sequence: 7.0, Frame: 11, Seq Loss: 31.729190084197874
# Scene: 50.0, Sequence: 8.0, Frame: 11, Seq Loss: 63.07670396728071
# Scene: 50.0, Sequence: 9.0, Frame: 11, Seq Loss: 52.182157505276116
# Scene: 50.0, Sequence: 10.0, Frame: 11, Seq Loss: 66.5284382738903
# Scene: 50.0, Sequence: 11.0, Frame: 11, Seq Loss: 135.40276947467606
# Scene: 50.0, Sequence: 12.0, Frame: 11, Seq Loss: 115.63696973217384
# Scene: 50.0, Sequence: 13.0, Frame: 11, Seq Loss: 39.99853898671574
# Scene: 50.0, Sequence: 14.0, Frame: 11, Seq Loss: 35.767594996983775
# Scene: 50.0, Sequence: 15.0, Frame: 11, Seq Loss: 20.51100287442678
# Scene: 50.0, Sequence: 16.0, Frame: 11, Seq Loss: 50.49942755341343
# Scene: 50.0, Sequence: 17.0, Frame: 11, Seq Loss: 20.385818731860702
# Scene: 50.0, Sequence: 18.0, Frame: 11, Seq Loss: 18.531807075235488
# Scene: 50.0, Sequence: 19.0, Frame: 11, Seq Loss: 44.188930201655786
# Scene: 50.0, Sequence: 20.0, Frame: 11, Seq Loss: 23.72395898886759
# Scene: 50.0, Sequence: 21.0, Frame: 11, Seq Loss: 16.390896887396934
# Scene: 50.0, Sequence: 22.0, Frame: 11, Seq Loss: 41.31066330085147
# Scene: 50.0, Sequence: 23.0, Frame: 11, Seq Loss: 20.595600360920347
# Scene: 50.0, Sequence: 24.0, Frame: 11, Seq Loss: 22.127419569773814
# Scene: 50.0, Sequence: 25.0, Frame: 11, Seq Loss: 38.872962507573746
# Scene: 50.0, Sequence: 26.0, Frame: 11, Seq Loss: 35.72360400167641
# Scene: 51.0, Sequence: 1.0, Frame: 11, Seq Loss: 28.83181732753247
# Scene: 51.0, Sequence: 2.0, Frame: 11, Seq Loss: 20.19051530412028
# Scene: 51.0, Sequence: 3.0, Frame: 11, Seq Loss: 33.136306860983474
# Scene: 51.0, Sequence: 4.0, Frame: 11, Seq Loss: 26.823095563223475
# Scene: 51.0, Sequence: 5.0, Frame: 11, Seq Loss: 20.996333508062445
# Scene: 51.0, Sequence: 6.0, Frame: 11, Seq Loss: 12.667375759098686
# Scene: 51.0, Sequence: 7.0, Frame: 11, Seq Loss: 23.17909606709871
# Scene: 51.0, Sequence: 8.0, Frame: 11, Seq Loss: 55.56779859980046
# Scene: 51.0, Sequence: 9.0, Frame: 11, Seq Loss: 15.66942446011326
# Scene: 51.0, Sequence: 10.0, Frame: 11, Seq Loss: 16.391571458636733
# Scene: 51.0, Sequence: 11.0, Frame: 11, Seq Loss: 31.921323255270345
# Scene: 51.0, Sequence: 12.0, Frame: 11, Seq Loss: 17.265241560219685
# Scene: 51.0, Sequence: 13.0, Frame: 11, Seq Loss: 30.583226731140286
# Scene: 51.0, Sequence: 14.0, Frame: 11, Seq Loss: 18.454948393681573
# Scene: 51.0, Sequence: 15.0, Frame: 11, Seq Loss: 39.21833835527246
# Scene: 51.0, Sequence: 16.0, Frame: 11, Seq Loss: 55.10619972241264
# Scene: 51.0, Sequence: 17.0, Frame: 11, Seq Loss: 67.19715841628414
# Scene: 51.0, Sequence: 18.0, Frame: 11, Seq Loss: 17.646106521251404
# Scene: 51.0, Sequence: 19.0, Frame: 11, Seq Loss: 20.18439327486513
# Scene: 51.0, Sequence: 20.0, Frame: 11, Seq Loss: 32.848009944973974
# Scene: 51.0, Sequence: 21.0, Frame: 11, Seq Loss: 23.013110744406323
# Scene: 51.0, Sequence: 22.0, Frame: 11, Seq Loss: 26.064513111692605
# Scene: 51.0, Sequence: 23.0, Frame: 11, Seq Loss: 97.35931194471291
# Scene: 51.0, Sequence: 24.0, Frame: 11, Seq Loss: 120.79862817140976
# Scene: 51.0, Sequence: 25.0, Frame: 11, Seq Loss: 103.164328798474
# Scene: 51.0, Sequence: 26.0, Frame: 11, Seq Loss: 90.83271425149574
# Scene: 52.0, Sequence: 1.0, Frame: 11, Seq Loss: 6.253333359668634
# Scene: 52.0, Sequence: 2.0, Frame: 11, Seq Loss: 7.772747778318438
# Scene: 52.0, Sequence: 3.0, Frame: 11, Seq Loss: 8.74831491562563
# Scene: 52.0, Sequence: 4.0, Frame: 11, Seq Loss: 10.952916376186906
# Scene: 52.0, Sequence: 5.0, Frame: 11, Seq Loss: 18.757062204644598
# Scene: 52.0, Sequence: 6.0, Frame: 11, Seq Loss: 14.419265430985726
# Scene: 52.0, Sequence: 7.0, Frame: 11, Seq Loss: 12.862709878087234
# Scene: 52.0, Sequence: 8.0, Frame: 11, Seq Loss: 28.954441856193597
# Scene: 52.0, Sequence: 9.0, Frame: 11, Seq Loss: 14.252433090873133
# Scene: 52.0, Sequence: 10.0, Frame: 11, Seq Loss: 5.096012740111778
# Scene: 52.0, Sequence: 11.0, Frame: 11, Seq Loss: 13.612288757756126
# Scene: 52.0, Sequence: 12.0, Frame: 11, Seq Loss: 7.608971728808651
# Scene: 52.0, Sequence: 13.0, Frame: 11, Seq Loss: 8.284865956177292
# Scene: 52.0, Sequence: 14.0, Frame: 11, Seq Loss: 6.423384047985186
# Scene: 52.0, Sequence: 15.0, Frame: 11, Seq Loss: 18.645418108501886
# Scene: 52.0, Sequence: 16.0, Frame: 11, Seq Loss: 5.253610163454119
# Scene: 52.0, Sequence: 17.0, Frame: 11, Seq Loss: 9.09555015534057
# Scene: 52.0, Sequence: 18.0, Frame: 11, Seq Loss: 10.90361166015256
# Scene: 52.0, Sequence: 19.0, Frame: 11, Seq Loss: 8.94396978734159
# Scene: 52.0, Sequence: 20.0, Frame: 11, Seq Loss: 4.430561853346276
# Scene: 52.0, Sequence: 21.0, Frame: 11, Seq Loss: 21.702626946445893
# Scene: 52.0, Sequence: 22.0, Frame: 11, Seq Loss: 21.483702830048387
# Scene: 52.0, Sequence: 23.0, Frame: 11, Seq Loss: 8.526114266961917
# Scene: 52.0, Sequence: 24.0, Frame: 11, Seq Loss: 10.328563881006373
# Scene: 52.0, Sequence: 25.0, Frame: 11, Seq Loss: 8.749087818792455
# Scene: 52.0, Sequence: 26.0, Frame: 11, Seq Loss: 7.29111150879365

# %%
print("1s: {}, 2s: {}, 3s: {}, 4s: {}".format(np.mean(valLoss1), np.mean(valLoss2), np.mean(valLoss3), np.mean(valLoss4)))
# Out:
# 1s: 11.41506158263851, 2s: 15.13690567416456, 3s: 17.95680730955954, 4s: 22.228192675476198

# %%
print("HitPreds: {}, TotalPreds: {}, Hit Rate: {}".format(hitPreds, totalPreds, hitPreds / totalPreds))
# Out:
# HitPreds: 648, TotalPreds: 1872, Hit Rate: 0.34615384615384615
